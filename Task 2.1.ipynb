# %%
pip install fredapi
# Out:
# Requirement already satisfied: fredapi in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (0.4.3)
# Requirement already satisfied: pandas in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from fredapi) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from pandas->fredapi) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from pandas->fredapi) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from pandas->fredapi) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->fredapi) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from fredapi import Fred
fred = Fred(api_key='e7d647d3a626afa2df49109657f48e3e')

# %%
bitcoinprice = fred.get_series('CBBTCUSD')
goldprice = fred.get_series('ID7108')
market = fred.get_series('SP500')
riskfreerate = fred.get_series('TB3MS')

# %%
df = pd.concat([bitcoinprice,goldprice,market,riskfreerate], axis=1)

# %%
df.columns = ('bitcoinprice','goldprice','market','riskfreerate')

# %%
df = df.loc['2018-05-01':'2021-12-12']

# %%
df = df.fillna(method='ffill')

# %%
#Will generate data with respect to monthly basis
df = df[df.index.day==1]
df
# Out:
#             bitcoinprice  goldprice   market  riskfreerate
# 2018-05-01       9072.29      473.7  2654.80          1.86
# 2018-06-01       7514.32      469.0  2734.62          1.90
# 2018-07-01       6349.50      453.1  2718.37          1.96
# 2018-08-01       7603.99      440.8  2813.36          2.03
# 2018-09-01       7191.08      433.5  2901.52          2.13
# 2018-10-01       6572.83      434.5  2924.59          2.25
# 2018-11-01       6344.00      444.0  2740.37          2.33
# 2018-12-01       4142.01      448.7  2760.17          2.37
# 2019-01-01       3826.10      464.4  2506.85          2.37
# 2019-02-01       3437.50      475.9  2706.53          2.39
# 2019-03-01       3806.17      467.3  2803.69          2.40
# 2019-04-01       4137.00      467.4  2867.19          2.38
# 2019-05-01       5321.15      463.7  2923.73          2.35
# 2019-06-01       8558.01      481.8  2752.06          2.17
# 2019-07-01      10570.62      506.1  2964.33          2.10
# 2019-08-01      10417.24      537.7  2953.56          1.95
# 2019-09-01       9769.64      554.7  2926.46          1.89
# 2019-10-01       8323.43      541.5  2940.25          1.65
# 2019-11-01       9268.00      539.2  3066.91          1.54
# 2019-12-01       7413.84      533.9  3140.98          1.54
# 2020-01-01       7174.32      555.0  3230.78          1.52
# 2020-02-01       9375.06      568.1  3225.52          1.52
# 2020-03-01       8490.30      595.4  2954.22          0.29
# 2020-04-01       6719.39      583.4  2470.50          0.14
# 2020-05-01       8813.90      617.3  2830.71          0.13
# 2020-06-01      10212.38      620.8  3055.73          0.16
# 2020-07-01       9239.09      642.6  3115.86          0.13
# 2020-08-01      11805.82      730.8  3271.12          0.10
# 2020-09-01      11911.74      707.7  3526.65          0.11
# 2020-10-01      10598.64      690.2  3380.80          0.10
# 2020-11-01      13784.52      694.6  3269.96          0.09
# 2020-12-01      18763.35      658.5  3662.45          0.09
# 2021-01-01      29391.09      696.6  3756.07          0.08
# 2021-02-01      33457.60      661.7  3773.86          0.04
# 2021-03-01      49652.19      622.7  3901.82          0.03
# 2021-04-01      58768.84      632.6  4019.87          0.02
# 2021-05-01      57868.94      656.1  4181.17          0.02
# 2021-06-01      36764.58      686.9  4202.04          0.04
# 2021-07-01      33538.49      686.9  4319.94          0.05
# 2021-08-01      39816.76      686.9  4395.26          0.05
